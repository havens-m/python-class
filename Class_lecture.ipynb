# %% [markdown]
# <a href="https://colab.research.google.com/github/havens-m/python-class/blob/main/Class_lecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
total = 0

for number in [1, 2, 3, 4, 5]:
    total = total + number

print (total)
# Out:
# 15

# %%
total = 0

for number in [1, 2, 3, 4, 5]:
  total += number #total =total + number

print (total)
# Out:
# 15

# %%
print(f'The total is {total}.')
# Out:
# The total is 15.

# %%
for i in range( 5, 10):
    print(i, end=' ')
# Out:
# 5 6 7 8 9

# %%
for i in range(0, 10, 2):
  print(i, end=' ')
# Out:
# 0 2 4 6 8

# %%
from decimal import Decimal

amount = Decimal ('0.01') + Decimal ('0.02')

print(amount)
# Out:
# 0.03

# %%
for number in range (10):
    if number % 2 == 0:
       continue
    print (number, end=' ')
# Out:
# 1 3 5 7 9

# %%
age = 20
citizen = True

if age >= 18 and citizen:
   print ('Eligible to vote')

if age < 18 or not citizen:
   print ('Not eligible in that rule set')
# Out:
# Eligible to vote

# %%
import statistics

data =[98, 76, 71, 87, 83, 90, 57, 79, 82, 94]

print(f'Mean:{statistics.mean(data)}')
print(f'Median:{statistics.median(data)}')
# Out:
# Mean:81.7
# Median:82.5
