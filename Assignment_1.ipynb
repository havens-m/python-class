# %% [markdown]
# <a href="https://colab.research.google.com/github/havens-m/python-class/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
T_f = 46
T_c = 5 * (T_f - 32) / 9
print(T_c)
# Out:
# 7.777777777777778

# %%
# Assign data to variables
principal = 172000
boe_rate = 2.25
rate_over_boe = 1.49

total_annual_rate = (boe_rate + rate_over_boe) / 100
interest = principal * total_annual_rate / 12
print(interest)
# Out:
# 536.0666666666667
